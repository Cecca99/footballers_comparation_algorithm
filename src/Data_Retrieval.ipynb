# %% [markdown]
# # **Data Retrieval**

# %% [markdown]
# ## **Installing and importing packages**

# %%
# !pip install soccerdata &> /dev/null
# !pip install dill &> /dev/null

# %%
from soccerdata import FBref
import pandas as pd
import dill
# Out:
# [03/02/24 11:23:44] INFO     No custom team name replacements found. You can configure these in       ]8;id=375185;file:///usr/local/lib/python3.10/dist-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=648982;file:///usr/local/lib/python3.10/dist-packages/soccerdata/_config.py#87\87]8;;\
#                              /root/soccerdata/config/teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=729152;file:///usr/local/lib/python3.10/dist-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=970573;file:///usr/local/lib/python3.10/dist-packages/soccerdata/_config.py#175\175]8;;\
#                              /root/soccerdata/config/league_dict.json.

# %% [markdown]
# ## **Data retrieving phase**

# %% [markdown]
# To take data on soccer players we are going to use *soccerdata*, a set of scrapers useful for retrieving soccer-related data from various platforms, such as FBref, Fotmob, and ESPN.
# We consider the FBref platform because it allows us to fetch data on individual soccer players, with the ability to filter results by football season (complete documentation of *soccerdata* at the following link: [Soccerdata](https://soccerdata.readthedocs.io/en/latest/index.html)).

# %% [markdown]
# FBref provides data on the following leagues:

# %%
FBref.available_leagues()
# Out:
# ['ARG-Primera División Argentina',
#  'AUS-A-League',
#  'AUT-Austrian Football Bundesliga',
#  'BEL-Challenger Pro League',
#  'BEL-Jupiler Pro League',
#  'BRA-Serie A Brasil',
#  'BUL-Bulgarian First League',
#  'Big 5 European Leagues Combined',
#  'COL-Primera A Colombia',
#  'CRO-Croatian Football League',
#  'CZE-Czech First League',
#  'DEN-Superliga',
#  'ECU-Liga Profesional Ecuador',
#  'ENG-Championship',
#  'ENG-Premier League',
#  'ESP-La Liga',
#  'ESP-Segunda División',
#  'FRA-Ligue 1',
#  'FRA-Ligue 2',
#  'GER-2. Fußball-Bundesliga',
#  'GER-Bundesliga',
#  'GRE-Super League Greece',
#  'HUN-Nemzeti Bajnokság I',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A',
#  'ITA-Serie B',
#  'JAP-J1 League',
#  'KOR-K League 1',
#  'KSA-Saudi Professional League',
#  'MEX-Liga MX',
#  'NED-Eerste Divisie',
#  'NED-Eredivisie',
#  'NOR-Eliteserien',
#  'PAR-Paraguayan Primera División',
#  'POL-Ekstraklasa',
#  'POR-Primeira Liga',
#  'RUS-Russian Premier League',
#  'SRB-Serbian SuperLiga',
#  'SUI-Swiss Super League',
#  'SWE-Allsvenskan',
#  'TUR-Süper Lig',
#  'URU-Uruguayan Primera División',
#  'USA-Major League Soccer']

# %% [markdown]
# Although the wide choice on leagues, we will consider only the following since they have the most data available.

# %% [markdown]
# We will also consider data for the 2022/2023 season as we would like to have available the most recent data possible but for an entire season.

# %%
fbref = FBref(leagues=['ARG-Primera División Argentina',
 'Big 5 European Leagues Combined',
 'ENG-Championship',
 'ESP-Segunda División',
 'FRA-Ligue 2',
 'GER-2. Fußball-Bundesliga',
 'ITA-Serie B',
 'MEX-Liga MX',
 'NED-Eredivisie',
 'POR-Primeira Liga',
 'USA-Major League Soccer'] , seasons='2022')
# Out:
# [03/02/24 11:23:48] INFO     Saving cached data to /root/soccerdata/data/FBref                        ]8;id=325164;file:///usr/local/lib/python3.10/dist-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=363548;file:///usr/local/lib/python3.10/dist-packages/soccerdata/_common.py#91\91]8;;\

# %% [markdown]
# We retrieved the following types of statistics:
# * Standard stats
# * Shooting stats
# * Passing stats
# * Passing types stats
# * Shot creation stats
# * Defensive stats
# * Possession related stats
# * Playing stats
# * Miscellaneous stats
#
# In the next phases we are going to filter by the statistics we are interested in.

# %%
standard = fbref.read_player_season_stats(stat_type='standard')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
standard.reset_index(inplace=True)

# %%
shooting = fbref.read_player_season_stats(stat_type='shooting')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
shooting.reset_index(inplace=True)

# %%
passing = fbref.read_player_season_stats(stat_type='passing')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
passing.reset_index(inplace=True)

# %%
passing_types = fbref.read_player_season_stats(stat_type='passing_types')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
passing_types.reset_index(inplace=True)

# %%
shot_creation = fbref.read_player_season_stats(stat_type='goal_shot_creation')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
shot_creation.reset_index(inplace=True)

# %%
defense = fbref.read_player_season_stats(stat_type='defense')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
defense.reset_index(inplace=True)

# %%
possession = fbref.read_player_season_stats(stat_type='possession')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
possession.reset_index(inplace=True)

# %%
playing = fbref.read_player_season_stats(stat_type='playing_time')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
playing.reset_index(inplace=True)

# %%
misc = fbref.read_player_season_stats(stat_type='misc')
# Out:
# /usr/local/lib/python3.10/dist-packages/soccerdata/_common.py:498: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
misc.reset_index(inplace=True)

# %%
playing = playing[playing['Playing Time']['MP'] > 0]

# %% [markdown]
# We retrieved different types of dataframes that we are going to merge based on player and team name.

# %%
df1 = standard.merge(right = shooting, on = ['league','season','team','player','nation','pos','age','born'])
df2 = df1.merge(right = passing, on = ['league','season','team','player','nation','pos','age','born'])
df3 = df2.merge(right = passing_types, on = ['league','season','team','player','nation','pos','age','born'])
df4 = df3.merge(right = shot_creation, on = ['league','season','team','player','nation','pos','age','born'], suffixes =['_1','_2'])
df5 = df4.merge(right = defense, on = ['league','season','team','player','nation','pos','age','born'])
df6 = df5.merge(right = possession, on = ['league','season','team','player','nation','pos','age','born'], suffixes =['_3','_4'])
df7 = df6.merge(right = playing, on = ['league','season','team','player','nation','pos','age','born'])
final_df = df7.merge(right = misc, on = ['league','season','team','player','nation','pos','age','born'])
# Out:
# <ipython-input-24-18bdcd6fc383>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df1 = standard.merge(right = shooting, on = ['league','season','team','player','nation','pos','age','born'])
# <ipython-input-24-18bdcd6fc383>:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df2 = df1.merge(right = passing, on = ['league','season','team','player','nation','pos','age','born'])
# <ipython-input-24-18bdcd6fc383>:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df3 = df2.merge(right = passing_types, on = ['league','season','team','player','nation','pos','age','born'])
# <ipython-input-24-18bdcd6fc383>:4: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df4 = df3.merge(right = shot_creation, on = ['league','season','team','player','nation','pos','age','born'], suffixes =['_1','_2'])
# <ipython-input-24-18bdcd6fc383>:5: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df5 = df4.merge(right = defense, on = ['league','season','team','player','nation','pos','age','born'])
# <ipython-input-24-18bdcd6fc383>:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df6 = df5.merge(right = possession, on = ['league','season','team','player','nation','pos','age','born'], suffixes =['_3','_4'])
# <ipython-input-24-18bdcd6fc383>:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df7 = df6.merge(right = playing, on = ['league','season','team','player','nation','pos','age','born'])
# <ipython-input-24-18bdcd6fc383>:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   final_df = df7.merge(right = misc, on = ['league','season','team','player','nation','pos','age','born'])

# %%
final_df
# Out:
#                               league season       team                player  \
#
# 0     ARG-Primera División Argentina   2223   Aldosivi           Andrés Ríos
# 1     ARG-Primera División Argentina   2223   Aldosivi  Bautista Kociubinski
# 2     ARG-Primera División Argentina   2223   Aldosivi        Brian Martínez
# 3     ARG-Primera División Argentina   2223   Aldosivi          David Torres
# 4     ARG-Primera División Argentina   2223   Aldosivi        Edwin Mosquera
# ...                              ...    ...        ...                   ...
# 9460         USA-Major League Soccer   2223  Vancouver   Sebastian Berhalter
# 9461         USA-Major League Soccer   2223  Vancouver          Simon Becher
# 9462         USA-Major League Soccer   2223  Vancouver          Thomas Hasal
# 9463         USA-Major League Soccer   2223  Vancouver      Tosaint Ricketts
# 9464         USA-Major League Soccer   2223  Vancouver      Tristan Blackmon
#
#      nation    pos age  born Playing Time_x         ... Performance_y      \
#                                          MP Starts  ...           Crs Int
# 0       ARG  FW,MF  32  1989              6      4  ...             4   1
# 1       ARG     MF  20  2001              8      8  ...             5  12
# 2       ARG  FW,MF  22  1999             18     14  ...            56   5
# 3       ARG  FW,DF  20  2001              3      0  ...             0   0
# 4       COL     FW  20  2001              1      0  ...             2   0
# ...     ...    ...  ..   ...            ...    ...  ...           ...  ..
# 9460    USA     MF  20  2001             18     11  ...            29  24
# 9461    USA     FW  22  1999              1      0  ...             0   0
# 9462    CAN     GK  22  1999             17     17  ...             0   1
# 9463    CAN  FW,DF  34  1987             23      2  ...             3   0
# 9464    USA     DF  25  1996             28     23  ...             2  32
#
#                                Aerial Duels
#      TklW PKwon PKcon OG Recov          Won  Lost  Won%
# 0       2     0     0  0    16            9    10  47.4
# 1      13     0     0  0    59           12     8  60.0
# 2       8  <NA>  <NA>  0  <NA>         <NA>  <NA>  <NA>
# 3       0     0     0  0     1            2     1  66.7
# 4       1     0     0  0     1            0     0  <NA>
# ...   ...   ...   ... ..   ...          ...   ...   ...
# 9460   20     0     0  0    93            5    10  33.3
# 9461    0     0     0  0     0            0     0  <NA>
# 9462    0     0     0  0    16            4     2  66.7
# 9463    3     0     0  0     8           22    26  45.8
# 9464   16     0     2  0   130           35    26  57.4
#
# [9465 rows x 191 columns]

# %% [markdown]
# ## **Saving dataframe**

# %% [markdown]
# Finally we save the dataframe on Mydrive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/DC_Inter/'

# %%
with open(path+'football_stats_2022_2023.pkl', 'wb') as f:
    dill.dump(final_df, f)
